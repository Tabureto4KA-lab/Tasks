# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as sts
import seaborn as sns
import random
import math

# %%
#1
data = pd.read_csv('insurance.csv', sep=',')

# %%
#2
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#3
fig, ax = plt.subplots(1, 4, figsize=(15, 4))
ax[0].hist(data['age'], edgecolor='black', color='blue', label='age')
ax[0].legend()
ax[1].hist(data['bmi'], edgecolor='black', color='red', label='bmi')
ax[1].legend()
ax[2].hist(data['children'], edgecolor='black', color='green', label='children')
ax[2].legend()
ax[3].hist(data['charges'], edgecolor='black', color='green', label='charges')
ax[3].legend()

plt.show()

# %%
#4
print('Меры центральной тенденции и меры разброса для индекса массы тела')
bmi_mean = np.mean(data.bmi)
bmi_moda = sts.mode(data.bmi)
bmi_med = np.median(data.bmi)

print('Среднее значение', bmi_mean)
print('Мода', bmi_moda)
print('Медиана', bmi_med)

bmi_raz = data.bmi.max() - data.bmi.min()
bmi_std = data.bmi.std()
bmi_iqr = sts.iqr(data.bmi, interpolation='midpoint')

print('Стандартное отклонение', bmi_std)
print('Размах', bmi_raz)
print('Межквартильный размах', bmi_iqr)

print('')
print('Меры центральной тенденции и меры разброса для расходов')
charges_mean = np.mean(data.charges)
charges_moda = sts.mode(data.charges)
charges_med = np.median(data.charges)

print('Среднее значение', charges_mean)
print('Мода', charges_moda)
print('Медиана', charges_med)

charges_raz = data.charges.max() - data.charges.min()
charges_std = data.charges.std()
charges_iqr = sts.iqr(data.charges, interpolation='midpoint')

print('Стандартное отклонение', charges_std)
print('Размах', charges_raz)
print('Межквартильный размах', charges_iqr)
# Out:
# Меры центральной тенденции и меры разброса для индекса массы тела
# Среднее значение 30.66339686098655
# Мода ModeResult(mode=32.3, count=13)
# Медиана 30.4
# Стандартное отклонение 6.098186911679017
# Размах 37.17
# Межквартильный размах 8.384999999999998
#
# Меры центральной тенденции и меры разброса для расходов
# Среднее значение 13270.422265141257
# Мода ModeResult(mode=1639.5631, count=2)
# Медиана 9382.033
# Стандартное отклонение 12110.011236693994
# Размах 62648.554110000005
# Межквартильный размах 11879.80148

# %%
fig, ax = plt.subplots(1, 4, figsize=(40, 15))
ax[0].hist(bmi_mean, edgecolor='black', color='blue', label='Средний индекс массы тела')
ax[0].hist(bmi_moda.mode, edgecolor='black', color='green', label='Наиболее часто встречающийся индекс массы тела')
ax[0].hist(bmi_med, edgecolor='black', color='red', label='Медиана индекса массы тела')
ax[0].legend()

ax[1].hist(charges_mean, edgecolor='black', color='blue', label='Средний расход')
ax[1].hist(charges_moda.mode, edgecolor='black', color='green', label='Наиболее часто встречающийся расход')
ax[1].hist(charges_med, edgecolor='black', color='red', label='Медиана расхода')
ax[1].legend()

ax[2].hist(bmi_raz, edgecolor='black', color='blue', label='Размах')
ax[2].hist(bmi_std, edgecolor='black', color='green', label='Стандартное отклонение')
ax[2].hist(bmi_iqr, edgecolor='black', color='red', label='Межквартильный размах')
ax[2].legend()

ax[3].hist(charges_raz, edgecolor='black', color='blue', label='Размах')
ax[3].hist(charges_std, edgecolor='black', color='green', label='Стандартное отклонение')
ax[3].hist(charges_iqr, edgecolor='black', color='red', label='Межквартильный размах')
ax[3].legend()

plt.show()

# %%
#5
sns.boxplot(x=data.age)
plt.show()

sns.boxplot(x=data.bmi)
plt.show()

sns.boxplot(x=data.children)
plt.show()

sns.boxplot(x=data.charges)
plt.show()

# %%
#6
def sample_gen(n):
    sample = []
    sample_mean = []
    for i in range(300):
        sample = random.sample(data.bmi.tolist(), n)
        sample_mean.append(np.array(sample).mean())    
    return sample_mean

# %%
sample_10 = sample_gen(10)
sample_50 = sample_gen(50)
sample_250 = sample_gen(250)
sample_500 = sample_gen(500)

# %%
fig, ax = plt.subplots(1, 4, figsize=(15, 4))

ax[0].hist(sample_10, label='Длина выборки = 10')
ax[0].legend()
ax[1].hist(sample_50, label='Длина выборки = 50')
ax[1].legend()
ax[2].hist(sample_250, label='Длина выборки = 250')
ax[2].legend()
ax[3].hist(sample_500, label='Длина выборки = 500')
ax[3].legend()

plt.show()

# %%
sns.displot(sample_500, kde = True)
plt.show()
# Out:
# C:\Users\vovaf\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
std_sample_10 = np.std(sample_10)
std_sample_50 = np.std(sample_50)
std_sample_250 = np.std(sample_250)
std_sample_500 = np.std(sample_500)

print(std_sample_10)
print(std_sample_50)
print(std_sample_250)
print(std_sample_500)
# Out:
# 1.8235920683114228
# 0.8155847842499269
# 0.33118016731438216
# 0.2281845341053278

# %%
print(np.mean(sample_10))
print(np.mean(sample_50))
print(np.mean(sample_250))
print(np.mean(sample_500))

# или

arr = np.array([std_sample_10, std_sample_50, std_sample_250, std_sample_500])
print(arr.std())
# Out:
# 30.689435
# 30.633969999999998
# 30.678189466666662
# 30.653914633333333
# 0.6314166688090534

# %%
#7
n = len(data.bmi)
med_x = np.mean(data.bmi)
sdx = np.std(data.bmi)
SE = sdx/math.sqrt(n)

print('Среднее значение всех элементов', med_x)

print('Доверительный интервал своими средствами')
interval_95 = [med_x - 1.96*SE, med_x + 1.96*SE]
print('Доверительный интервал 95%', interval_95)
interval_99 = [med_x - 2.58*SE, med_x + 2.58*SE]
print('Доверительный интервал 99%', interval_99)

print('Доверительный интервал с помощью библиотеки scipy.stats')
print('Доверительный интервал 95%', sts.t.interval(confidence=0.95, df=len(data.bmi)-1, loc=np.mean(data.bmi), scale=sts.sem(data.bmi)))
print('Доверительный интервал 99%', sts.t.interval(confidence=0.99, df=len(data.bmi)-1, loc=np.mean(data.bmi), scale=sts.sem(data.bmi)))
# Out:
# Среднее значение всех элементов 30.66339686098655
# Доверительный интервал своими средствами
# Доверительный интервал 95% [30.336759097652553, 30.990034624320543]
# Доверительный интервал 99% [30.233434907210167, 31.09335881476293]
# Доверительный интервал с помощью библиотеки scipy.stats
# Доверительный интервал 95% (30.336346903054107, 30.99044681891899)
# Доверительный интервал 99% (30.233355575431627, 31.09343814654147)

# %%
n = len(data.charges)
med_x = np.mean(data.charges)
sdx = np.std(data.charges)
SE = sdx/math.sqrt(n)

print('Среднее значение всех элементов', med_x)

print('Доверительный интервал своими средствами')
interval_95 = [med_x - 1.96*SE, med_x + 1.96*SE]
print('Доверительный интервал 95%', interval_95)
interval_99 = [med_x - 2.58*SE, med_x + 2.58*SE]
print('Доверительный интервал 99%', interval_99)

print('Доверительный интервал с помощью библиотеки scipy.stats')
print('Доверительный интервал 95%', sts.t.interval(confidence=0.95, df=len(data.charges)-1, loc=np.mean(data.charges), scale=sts.sem(data.charges)))
print('Доверительный интервал 99%', sts.t.interval(confidence=0.99, df=len(data.charges)-1, loc=np.mean(data.charges), scale=sts.sem(data.charges)))
# Out:
# Среднее значение всех элементов 13270.422265141257
# Доверительный интервал своими средствами
# Доверительный интервал 95% [12621.772585885332, 13919.071944397181]
# Доверительный интервал 99% [12416.58748326356, 14124.257047018953]
# Доверительный интервал с помощью библиотеки scipy.stats
# Доверительный интервал 95% (12620.954034192644, 13919.890496089869)
# Доверительный интервал 99% (12416.429943203952, 14124.414587078561)

# %%
#8
sample_bmi = data['bmi'].sample(500)
sample_charges = data['charges'].sample(500)

test_ks_bmi = sts.kstest(sts.zscore(sample_bmi), 'norm')
print(test_ks_bmi)

test_ks_charges = sts.kstest(sts.zscore(sample_charges), 'norm')
print(test_ks_charges)

fig, ax = plt.subplots(1, 2, figsize=(30,15))
sts.probplot(sample_bmi, dist='norm', plot=ax[0])
ax[0].set_title('Probability Plot of bmi')
sts.probplot(sample_charges, plot=ax[1])
ax[1].set_title('Probability Plot of charges')
plt.show()
# Out:
# KstestResult(statistic=0.0420221466449876, pvalue=0.3311370024644609, statistic_location=-0.035155549440476976, statistic_sign=1)
# KstestResult(statistic=0.16957743492823096, pvalue=4.867346312766858e-13, statistic_location=0.046194947038317904, statistic_sign=1)

# %%
#9
data = pd.read_csv('ECDCCases.csv', sep=',')

# %%
#10
for column in data.columns:
    missing = np.mean(data[column].isna()*100)
    print(f' {column} : {round(missing,1)}%')
# Out:
#  dateRep : 0.0%
#  day : 0.0%
#  month : 0.0%
#  year : 0.0%
#  cases : 0.0%
#  deaths : 0.0%
#  countriesAndTerritories : 0.0%
#  geoId : 0.4%
#  countryterritoryCode : 0.2%
#  popData2019 : 0.2%
#  continentExp : 0.0%
#  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 : 4.7%

# %%
data.drop('Cumulative_number_for_14_days_of_COVID-19_cases_per_100000', axis = 1, inplace=True)
data.drop('geoId', axis = 1, inplace=True)

# %%
for column in data.columns:
    missing = np.mean(data[column].isna()*100)
    print(f' {column} : {round(missing,1)}%')
# Out:
#  dateRep : 0.0%
#  day : 0.0%
#  month : 0.0%
#  year : 0.0%
#  cases : 0.0%
#  deaths : 0.0%
#  countriesAndTerritories : 0.0%
#  countryterritoryCode : 0.2%
#  popData2019 : 0.2%
#  continentExp : 0.0%

# %%
data.countryterritoryCode.fillna('Other', inplace=True)

# %%
data.countryterritoryCode.value_counts()
# Out:
# countryterritoryCode
# DNK      350
# MEX      350
# CAN      350
# CHN      350
# CZE      350
#         ...
# LSO      214
# Other    123
# SLB       60
# MHL       47
# VUT       34
# Name: count, Length: 213, dtype: int64

# %%
median = data.popData2019.median()
data.popData2019.fillna(median, inplace=True)

# %%
data.popData2019.value_counts()
# Out:
# popData2019
# 7169456.0      388
# 5806081.0      350
# 127575529.0    350
# 10649800.0     350
# 145872260.0    350
#               ...
# 850891.0       227
# 2125267.0      214
# 669821.0        60
# 58791.0         47
# 299882.0        34
# Name: count, Length: 212, dtype: int64

# %%
for column in data.columns:
    missing = np.mean(data[column].isna()*100)
    print(f' {column} : {round(missing,1)}%')
# Out:
#  dateRep : 0.0%
#  day : 0.0%
#  month : 0.0%
#  year : 0.0%
#  cases : 0.0%
#  deaths : 0.0%
#  countriesAndTerritories : 0.0%
#  countryterritoryCode : 0.0%
#  popData2019 : 0.0%
#  continentExp : 0.0%

# %%
data.isna().sum()
# Out:
# dateRep                    0
# day                        0
# month                      0
# year                       0
# cases                      0
# deaths                     0
# countriesAndTerritories    0
# countryterritoryCode       0
# popData2019                0
# continentExp               0
# dtype: int64

# %%
#11
data.describe()
# Out:
#                 day         month          year          cases        deaths  \
# count  61904.000000  61904.000000  61904.000000   61904.000000  61904.000000
# mean      15.629232      7.067104   2019.998918    1155.079026     26.053987
# std        8.841624      2.954816      0.032881    6779.010824    131.222948
# min        1.000000      1.000000   2019.000000   -8261.000000  -1918.000000
# 25%        8.000000      5.000000   2020.000000       0.000000      0.000000
# 50%       15.000000      7.000000   2020.000000      15.000000      0.000000
# 75%       23.000000     10.000000   2020.000000     273.000000      4.000000
# max       31.000000     12.000000   2020.000000  234633.000000   4928.000000
#
#         popData2019
# count  6.190400e+04
# mean   4.091909e+07
# std    1.529798e+08
# min    8.150000e+02
# 25%    1.324820e+06
# 50%    7.169456e+06
# 75%    2.851583e+07
# max    1.433784e+09

# %%
data.boxplot(column='cases', figsize=(30,15))
# Out:
# <Axes: >

# %%
data.boxplot(column='deaths', figsize=(30,15))
# Out:
# <Axes: >

# %%
data.boxplot(column='popData2019', figsize=(30,15))
# Out:
# <Axes: >

# %%
data[(data['deaths']>3000)]
# Out:
#           dateRep  day  month  year   cases  deaths   countriesAndTerritories  \
# 2118   02/10/2020    2     10  2020   14001    3351                 Argentina
# 16908  07/09/2020    7      9  2020   -8261    3800                   Ecuador
# 37038  09/10/2020    9     10  2020    4936    3013                    Mexico
# 44888  14/08/2020   14      8  2020    9441    3935                      Peru
# 44909  24/07/2020   24      7  2020    4546    3887                      Peru
# 59007  12/12/2020   12     12  2020  234633    3343  United_States_of_America
# 59009  10/12/2020   10     12  2020  220025    3124  United_States_of_America
# 59016  03/12/2020    3     12  2020  203311    3190  United_States_of_America
# 59239  24/04/2020   24      4  2020   26543    3179  United_States_of_America
# 59245  18/04/2020   18      4  2020   30833    3770  United_States_of_America
# 59247  16/04/2020   16      4  2020   30148    4928  United_States_of_America
#
#       countryterritoryCode  popData2019 continentExp
# 2118                   ARG   44780675.0      America
# 16908                  ECU   17373657.0      America
# 37038                  MEX  127575529.0      America
# 44888                  PER   32510462.0      America
# 44909                  PER   32510462.0      America
# 59007                  USA  329064917.0      America
# 59009                  USA  329064917.0      America
# 59016                  USA  329064917.0      America
# 59239                  USA  329064917.0      America
# 59245                  USA  329064917.0      America
# 59247                  USA  329064917.0      America

# %%
data[(data['deaths']>3000)].value_counts('countriesAndTerritories')
# Out:
# countriesAndTerritories
# United_States_of_America    6
# Peru                        2
# Argentina                   1
# Ecuador                     1
# Mexico                      1
# Name: count, dtype: int64

# %%
#12
duplicate = data.duplicated()
data[duplicate]
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 3      12/12/2020   12     12  2020    113      11             Afghanistan
# 218    12/05/2020   12      5  2020    285       2             Afghanistan
# 48010  29/05/2020   29      5  2020      0       0             Saint_Lucia
# 48073  28/03/2020   28      3  2020      0       0             Saint_Lucia
#
#       countryterritoryCode  popData2019 continentExp
# 3                      AFG   38041757.0         Asia
# 218                    AFG   38041757.0         Asia
# 48010                  LCA     182795.0      America
# 48073                  LCA     182795.0      America

# %%
data.drop_duplicates()
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      14/12/2020   14     12  2020    746       6             Afghanistan
# 1      13/12/2020   13     12  2020    298       9             Afghanistan
# 2      12/12/2020   12     12  2020    113      11             Afghanistan
# 4      11/12/2020   11     12  2020     63      10             Afghanistan
# 5      10/12/2020   10     12  2020    202      16             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 61899  25/03/2020   25      3  2020      0       0                Zimbabwe
# 61900  24/03/2020   24      3  2020      0       1                Zimbabwe
# 61901  23/03/2020   23      3  2020      0       0                Zimbabwe
# 61902  22/03/2020   22      3  2020      1       0                Zimbabwe
# 61903  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       countryterritoryCode  popData2019 continentExp
# 0                      AFG   38041757.0         Asia
# 1                      AFG   38041757.0         Asia
# 2                      AFG   38041757.0         Asia
# 4                      AFG   38041757.0         Asia
# 5                      AFG   38041757.0         Asia
# ...                    ...          ...          ...
# 61899                  ZWE   14645473.0       Africa
# 61900                  ZWE   14645473.0       Africa
# 61901                  ZWE   14645473.0       Africa
# 61902                  ZWE   14645473.0       Africa
# 61903                  ZWE   14645473.0       Africa
#
# [61900 rows x 10 columns]

# %%
#13
data2 = pd.read_csv('bmi.csv', sep=',')
data2.is_copy = False

# %%
northwest_data = data2[data2.region=='northwest'] 
southwest_data = data2[data2.region=='southwest']

# %%
northwest_data_array = np.array(northwest_data)
southwest_data_array = np.array(southwest_data)

northwest_data_array.resize(325, )
southwest_data_array.resize(325, )

# %%
res1_shapiro = sts.shapiro(northwest_data)
res2_shapiro = sts.shapiro(southwest_data)
print(res1_shapiro, '\n', res2_shapiro)
# Out:
# ShapiroResult(statistic=0.9954646825790405, pvalue=0.4655335247516632)
#  ShapiroResult(statistic=0.9949268698692322, pvalue=0.3629520535469055)

# %%
res_bartlett = sts.bartlett(northwest_data_array, southwest_data_array)
print(res_bartlett)
# Out:
# BartlettResult(statistic=3.4000745256459286, pvalue=0.06519347353581818)

# %%
t_res = sts.ttest_ind(northwest_data_array, southwest_data_array)
print(t_res)
# Out:
# TtestResult(statistic=-3.2844171500398582, pvalue=0.001076958496307695, df=648.0)

# %%
#14
result = {'N': [1,2,3,4,5,6],
          'num_drops': [97,98,109,95,97,104]
          }

df_result = pd.DataFrame(result)

# %%
df_result
# Out:
#    N  num_drops
# 0  1         97
# 1  2         98
# 2  3        109
# 3  4         95
# 4  5         97
# 5  6        104

# %%
sts.chisquare(df_result['num_drops'])
# Out:
# Power_divergenceResult(statistic=1.44, pvalue=0.9198882077437889)

# %%
#15
data = pd.DataFrame({'Женат': [89,17,11,43,22,1],
                     'Гражданский брак': [80,22,20,35,6,4],
                     'Не состоит в отношениях': [35,44,35,6,8,22]})
data.index = ['Полный рабочий день',
              'Частичная занятость',
              'Временно не работает',
              'На домохозяйстве',
              'На пенсии',
              'Учёба']

data
# Out:
#                       Женат  Гражданский брак  Не состоит в отношениях
# Полный рабочий день      89                80                       35
# Частичная занятость      17                22                       44
# Временно не работает     11                20                       35
# На домохозяйстве         43                35                        6
# На пенсии                22                 6                        8
# Учёба                     1                 4                       22

# %%
sts.chi2_contingency(data)[:3]
# Out:
# (122.29654948595365, 1.7291616900960234e-21, 10)
